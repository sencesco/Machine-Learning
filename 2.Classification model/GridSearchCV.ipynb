# %% [markdown]
# # Data: https://www.kaggle.com/teejmahal20/airline-passenger-satisfaction

# %% [markdown]
# # Import data

# %%
import pandas as pd
import seaborn as sns

# %%
# data1 = pd.read_csv('Airline1.csv')
# data2 = pd.read_csv('Airline2.csv')
# data = pd.concat([data1,data2])

data = pd.read_csv('Airline2_tiny.csv')

# %%
data.shape
# Out:
# (129880, 25)

# %%
data.tail()
# Out:
#       Gender      Customer Type  Age   Type of Travel     Class  \
# 4994  Female     Loyal Customer   41  Personal Travel  Eco Plus
# 4995    Male     Loyal Customer   53  Business travel  Business
# 4996    Male  disloyal Customer   21  Business travel       Eco
# 4997    Male     Loyal Customer   59  Business travel       Eco
# 4998    Male  disloyal Customer   25  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 4994              746                      3
# 4995             3095                      3
# 4996              125                      4
# 4997              302                      4
# 4998              738                      1
#
#       Departure/Arrival time convenient  Ease of Online booking  \
# 4994                                  5                       3
# 4995                                  3                       3
# 4996                                  0                       4
# 4997                                  3                       3
# 4998                                  4                       2
#
#       Gate location  ...  Inflight entertainment  On-board service  \
# 4994              4  ...                       3                 3
# 4995              3  ...                       3                 3
# 4996              4  ...                       5                 3
# 4997              3  ...                       4                 5
# 4998              4  ...                       3                 5
#
#       Leg room service  Baggage handling  Checkin service  Inflight service  \
# 4994                 3                 3                5                 3
# 4995                 3                 3                3                 3
# 4996                 4                 4                1                 1
# 4997                 2                 4                1                 2
# 4998                 5                 5                4                 5
#
#       Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 4994            4                           4                      28.0
# 4995            5                           0                       0.0
# 4996            5                          58                      60.0
# 4997            4                           0                       0.0
# 4998            3                          86                      71.0
#
#                  satisfaction
# 4994  neutral or dissatisfied
# 4995                satisfied
# 4996                satisfied
# 4997                satisfied
# 4998  neutral or dissatisfied
#
# [5 rows x 23 columns]

# %%
X = data.iloc[:,:-1]

# %%
X.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
# 3    Male     Loyal Customer   44  Business travel  Business             3377
# 4  Female     Loyal Customer   49  Business travel       Eco             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              4  ...             3
# 1                       3              1  ...             5
# 2                       2              4  ...             2
# 3                       0              2  ...             4
# 4                       4              3  ...             2
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 5                 5
# 1                       4                 4                 4
# 2                       2                 4                 1
# 3                       1                 1                 1
# 4                       2                 2                 2
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 5                2                 5            5
# 1                 4                3                 4            5
# 2                 3                2                 2            2
# 3                 1                3                 1            4
# 4                 2                4                 2            4
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          50                      44.0
# 1                           0                       0.0
# 2                           0                       0.0
# 3                           0                       6.0
# 4                           0                      20.0
#
# [5 rows x 22 columns]

# %%
y = data.iloc[:,-1]

# %%
y.head()
# Out:
# 0                  satisfied
# 1                  satisfied
# 2    neutral or dissatisfied
# 3                  satisfied
# 4                  satisfied
# Name: satisfaction, dtype: object

# %% [markdown]
# # Handling missing data - Numeric type

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
#X.dtypes

# %%
numerical_cols = list(np.where((X.dtypes == np.int64) | (X.dtypes == np.float64))[0])

# %%
imp_mean.fit(X.iloc[:,numerical_cols])
# Out:
# SimpleImputer()

# %%
X.iloc[:,numerical_cols] = imp_mean.transform(X.iloc[:,numerical_cols])

# %% [markdown]
# ### Handling missing string data

# %%
string_cols = list(np.where((X.dtypes == object))[0])

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
imp_mean.fit(X.iloc[:,string_cols])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
X.iloc[:,string_cols] = imp_mean.transform(X.iloc[:,string_cols])

# %% [markdown]
# # One Hot encoder method

# %%
def OneHotEncoderMethod(indices, data):
    from sklearn.compose import ColumnTransformer
    from sklearn.preprocessing import OneHotEncoder
    columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(),indices )], remainder='passthrough')
    return columnTransformer.fit_transform(data)

# %% [markdown]
# # Label encoding method

# %%
def LabelEncoderMethod(series):
    from sklearn import preprocessing
    le = preprocessing.LabelEncoder()
    le.fit(series)
    #print('Actual labels',le.classes_)
    #print('Encoding values',le.transform(pd.unique(series)))
    return le.transform(series)

# %% [markdown]
# # Label encoding target feature

# %%
y = LabelEncoderMethod(y)

# %% [markdown]
# # Encoding selection for X

# %%
def EncodingSelection(X, threshold=10):
    # Step 01 : Select the string col
    string_cols = list(np.where((X.dtypes == object))[0])
    one_hot_encoding_indices = []

    # Step 02: The number of categoty is 2 and more than threshold, label encode
    for col in string_cols:
        lenght = len(pd.unique(X[X.columns[col]]))
        if lenght == 2 or lenght > threshold:
            X[X.columns[col]] = LabelEncoderMethod(X[X.columns[col]])
        else:
            one_hot_encoding_indices.append(col)

    # Step 03: One hot encode otherwise
    X = OneHotEncoderMethod(one_hot_encoding_indices, X)
    return X

# %%
X = EncodingSelection(X)

# %%
X.shape
# Out:
# (4999, 24)

# %% [markdown]
# # Feature selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
kbest = SelectKBest(score_func=chi2, k='all')

# %%
from sklearn import preprocessing
MMS = preprocessing.MinMaxScaler()

# %%
K_features = 10

# %%
x_temp = MMS.fit_transform(X)

# %%
x_temp = kbest.fit(x_temp,y)

# %%
best_features = np.argsort(x_temp.scores_)[-K_features:]

# %%
best_features
# Out:
# array([ 8,  7, 15, 21, 14, 13,  4,  1,  0,  6], dtype=int64)

# %%
features_to_delete = best_features = np.argsort(x_temp.scores_)[:-K_features]

# %%
X = np.delete(X, features_to_delete, axis=1)

# %%
X.shape
# Out:
# (4999, 10)

# %%
del x_temp

# %% [markdown]
# # Train test split

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
print(X_train.shape)
# Out:
# (3999, 10)

# %% [markdown]
# # Feature scaling

# %% [markdown]
# ### Standardization: (X - mean(X)) / std(X)

# %% [markdown]
# ### Normalization = (x - min(x)) / (max(x) - min(x))

# %%
from sklearn import preprocessing

# %%
sc = preprocessing.StandardScaler(with_mean=False)

# %%
sc.fit(X_train)
# Out:
# StandardScaler(with_mean=False)

# %%
X_train = sc.transform(X_train)

# %%
print(X_train.shape)
# Out:
# (3999, 10)

# %%
X_test = sc.transform(X_test)

# %%
print(X_test.shape)
# Out:
# (1000, 10)

# %% [markdown]
# #### The data is ready!!

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)
# Out:
# Current Time = 17:07:24

# %% [markdown]
# # Building KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

params = {'n_neighbors':[4,5,6,7],
              'leaf_size':[1,3,5],
              'algorithm':['auto', 'kd_tree'],
               'weights': ['uniform', 'distance']
         }
cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# Fitting 2 folds for each of 48 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.9s
# Best Estimator KNeighborsClassifier(leaf_size=1)
# Best score 0.8774673417446253
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    3.0s finished

# %% [markdown]
# # Building Logistic regression model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

params = {'solver':['newton-cg', 'lbfgs', 'liblinear'],
          'penalty': ['l1', 'l2'],
          'C':[100, 10, 1.0, 0.1, 0.01]
         }

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# Fitting 2 folds for each of 30 candidates, totalling 60 fits
# Best Estimator LogisticRegression(C=0.01, solver='newton-cg')
# Best score 0.8295203666687819
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  60 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.0s finished

# %% [markdown]
# # Building GaussianNB model

# %%
from sklearn.naive_bayes import GaussianNB
model_GNB = GaussianNB()
model_GNB.fit(X_train,y_train)
y_pred = model_GNB.predict(X_test)
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred, y_test))
# Out:
# 0.84
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       564
#            1       0.82      0.81      0.82       436
#
#     accuracy                           0.84      1000
#    macro avg       0.84      0.84      0.84      1000
# weighted avg       0.84      0.84      0.84      1000

# %% [markdown]
# # Building SVM (SVC) model

# %%
from sklearn.svm import SVC
model = SVC()

params = {
    'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'C' : [1,5,10],
    'degree' : [3,8],
    'coef0' : [0.01,10,0.5],
    'gamma' : ['auto','scale']
}

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 265 out of 288 | elapsed:  2.4min remaining:   12.7s
# Best Estimator SVC(C=5, coef0=0.01)
# Best score 0.9168629045108148
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:  9.6min finished

# %% [markdown]
# # Building Decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

params = {'max_leaf_nodes': list(range(2, 100)),
          'min_samples_split': [2, 3, 4],
         }

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 2 folds for each of 294 candidates, totalling 588 fits
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# Best Estimator DecisionTreeClassifier(max_leaf_nodes=29, min_samples_split=4)
# Best score 0.9098148654372425
# [Parallel(n_jobs=-1)]: Done 588 out of 588 | elapsed:    0.8s finished

# %% [markdown]
# # Building Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()


param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 2 folds for each of 294 candidates, totalling 588 fits
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   11.5s
# Best Estimator RandomForestClassifier(max_leaf_nodes=82, min_samples_split=4)
# Best score 0.9225835186933584
# [Parallel(n_jobs=-1)]: Done 588 out of 588 | elapsed:   16.5s finished

# %% [markdown]
# # Building ADABoost model

# %%
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier()

params = {
     'n_estimators': np.arange(10,300,10),
     'learning_rate': [0.01, 0.05, 0.1, 1],
 }

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# Fitting 2 folds for each of 116 candidates, totalling 232 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    1.4s
# Best Estimator AdaBoostClassifier(learning_rate=1, n_estimators=30)
# Best score 0.8938313525749858
# [Parallel(n_jobs=-1)]: Done 232 out of 232 | elapsed:   12.8s finished

# %% [markdown]
# # Building XGBoost model

# %%
import xgboost as xgb
model = xgb.XGBClassifier()

params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5],
        'n_estimators': [100,500,1000],
        'learning_rate':[0.01,0.3,0.5,0.1],
        'reg_lambda':[1,2]

        }

cv = StratifiedKFold(n_splits=2)
grid_search_cv = GridSearchCV(estimator=model,
                              param_grid = params, verbose=1, cv=cv,scoring='f1',n_jobs=-1 )



grid_search_cv.fit(X_train, y_train)
print("Best Estimator", grid_search_cv.best_estimator_)
print("Best score", grid_search_cv.best_score_)
# Out:
# Fitting 2 folds for each of 9720 candidates, totalling 19440 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 1776 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 2426 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 3176 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 4026 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 4976 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 6026 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done 7176 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 8426 tasks      | elapsed: 30.2min
# [Parallel(n_jobs=-1)]: Done 9776 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 11226 tasks      | elapsed: 39.9min
# [Parallel(n_jobs=-1)]: Done 12776 tasks      | elapsed: 45.3min
# [Parallel(n_jobs=-1)]: Done 14426 tasks      | elapsed: 51.2min
# [Parallel(n_jobs=-1)]: Done 16176 tasks      | elapsed: 57.7min
# [Parallel(n_jobs=-1)]: Done 18026 tasks      | elapsed: 64.4min
# [Parallel(n_jobs=-1)]: Done 19440 out of 19440 | elapsed: 69.6min finished
# C:\Users\chaan\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:27:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best Estimator XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.5, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=12, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1.0,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# Best score 0.9267223852716081

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)
# Out:
# Current Time = 18:27:14
